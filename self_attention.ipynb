# %% [markdown]
# <a href="https://colab.research.google.com/github/kmouleejunhyuk/attention-is-all-you-need/blob/main/self_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About code

# %%
# reproducing self attention and transformer
# source paper: Attention is all you need, Vaswani et al
# https://arxiv.org/pdf/1706.03762.pdf

# %%
# why attention:  inherently sequential nature of rnn, lstm precludes parallelization within training examples, critical at longer seq
# as in the paper, transformer layer stack will be 6

# %%
import torch
import numpy as np
import pandas as pd
import sklearn

# %% [markdown]
# # Code reproduction

# %% [markdown]
# #### 1. Scaled Dot-Product Attention(no mask)

# %% [markdown]
# ![캡처.JPG](data:image/jpeg;base64,...)

# %%
class dot_attention(torch.nn):
    def __init__(self):
        super(dot_attention. self).__init__()

        self.Q_weight
        self.K_weight
        self.matmul=torch.nn.matmul()

    def foward(x):  
        Q=self.matmul(Q_weight, x)
        K=self.matmul(K_weight, x)  
        V=x   
        
        attention_score=torch.softmax(torch.multiply(Q, torch.transpose(K))/torch.sqrt(d_k))
        out=attention_score*V
